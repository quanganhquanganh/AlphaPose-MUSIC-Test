# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
! pip install pyyaml==5.2
! pip install scipy==1.1.0
import torch
print(torch.__version__)
print(torch.version.cuda)
import yaml, scipy
print(yaml.__version__)
print(scipy.__version__)
# Out:
# ...
#      |████████████████████████████████| 265 kB 5.4 MB/s
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.2-cp37-cp37m-linux_x86_64.whl size=44225 sha256=4d03c45157fb292e74fbc4a4493cad23197dd22b85d88605f13979a1e1b9c00a
#   Stored in directory: /root/.cache/pip/wheels/c5/67/65/80b02387630c3794fc9bab68ca0de3dd87d639d65936026527
# Successfully built pyyaml
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 31.2 MB 1.3 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# ...

# %%
RESEARCH_DIR = "/content/drive/My Drive"
os.chdir(RESEARCH_DIR)
os.getcwd()
# Out:
# '/content/drive/My Drive'

# %%
# !rm -rf AlphaPose
# !git clone https://github.com/quanganhquanganh/AlphaPose.git
# Out:
# Cloning into 'AlphaPose'...
# remote: Enumerating objects: 2394, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 2394 (delta 35), reused 12 (delta 5), pack-reused 2318
# Receiving objects: 100% (2394/2394), 108.49 MiB | 11.98 MiB/s, done.
# Resolving deltas: 100% (1195/1195), done.
# Checking out files: 100% (280/280), done.

# %%
# !python -m pip install cython
# !sudo apt-get install libyaml-dev
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libyaml-doc
# The following NEW packages will be installed:
#   libyaml-dev
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 55.7 kB of archives.
# After this operation, 246 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libyaml-dev amd64 0.1.7-2ubuntu3 [55.7 kB]
# Fetched 55.7 kB in 0s (131 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
import os
os.chdir('/content/drive/My Drive/AlphaPose')
print(os.getcwd())
! python setup.py build develop
# Out:
# /content/drive/My Drive/AlphaPose
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/alphapose
# copying alphapose/__init__.py -> build/lib.linux-x86_64-3.7/alphapose
# copying alphapose/opt.py -> build/lib.linux-x86_64-3.7/alphapose
# copying alphapose/version.py -> build/lib.linux-x86_64-3.7/alphapose
# creating build/lib.linux-x86_64-3.7/trackers
# copying trackers/__init__.py -> build/lib.linux-x86_64-3.7/trackers
# copying trackers/tracker_api.py -> build/lib.linux-x86_64-3.7/trackers
# copying trackers/tracker_cfg.py -> build/lib.linux-x86_64-3.7/trackers
# creating build/lib.linux-x86_64-3.7/alphapose/datasets
# copying alphapose/datasets/__init__.py -> build/lib.linux-x86_64-3.7/alphapose/datasets
# copying alphapose/datasets/coco_det.py -> build/lib.linux-x86_64-3.7/alphapose/datasets
# copying alphapose/datasets/coco_wholebody.py -> build/lib.linux-x86_64-3.7/alphapose/datasets
# ...

# %%
# !pip install -U -q PyDrive
# !pip install -U -q tenacity==5.1.5
# !pip install -U -q mega.py

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from mega import Mega
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
mega = Mega()
m = mega.login()

! mkdir '/content/drive/My Drive/AlphaPose/trackers/weights'
! mkdir '/content/drive/My Drive/AlphaPose/detector/yolo/data'
file_id = '1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/drive/My Drive/AlphaPose/detector/yolo/data/yolov3-spp.weights')

# ! mkdir /content/AlphaPose/detector/tracker/data
# file_id = '1nlnuYfGNuHWZztQHXwVZSL_FvfE551pA'
# downloaded = drive.CreateFile({'id': file_id})
# downloaded.GetContentFile('/content/AlphaPose/detector/tracker/data/jde.1088x608.uncertainty.pt')

file_url = 'https://mega.nz/file/YTZFnSJY#wlbo_5oa2TpDAGyWCTKTX1hh4d6DvJhh_RUA2z6i_so'
m.create_folder('/content/drive/My Drive/AlphaPose/trackers/weights')
m.download_url(file_url, '/content/drive/My Drive/AlphaPose/trackers/weights', 'osnet_ain_x1_0_msmt17_256x128_amsgrad_ep50_lr0.0015_coslr_b64_fb10_softmax_labsmth_flip_jitter.pth')

file_id = '1kQhnMRURFiy7NsdS8EFL-8vtqEXOgECn'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/drive/My Drive/AlphaPose/pretrained_models/fast_res50_256x192.pth')

file_id = '1wX1Z2ZOoysgSNovlgiEtJKpbR8tUBWYR'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/drive/My Drive/AlphaPose/pretrained_models/multi_domain_fast50_dcn_combined_256x192.pth')

file_id = '14Qn9gxm-EVzqFi7v25Y5TqKIvrFLy_BR'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/drive/My Drive/AlphaPose/pretrained_models/noface_fast50_dcn_combined_256x192.pth')

# %%
YOUTUBE_ID = 'xk3BvNLeNgw'

# !pip install yt-dlp
# !rm -df "/content/youtube.mp4"
# !rm -df "/content/video.mp4"
# download the youtube with the given ID
# !yt-dlp -f 'bestvideo[ext=mp4]' --output "/content/youtube.%(ext)s" https://www.youtube.com/watch?v=$YOUTUBE_ID
# Remove previously extracted clips
# !rm -rf '/content/media'
# !mkdir '/content/media'
# !ffmpeg -i "/content/youtube.mp4" -c copy -map 0 -segment_time 10 -f segment -to "00:00:50" -segment_format mp4 -reset_timestamps 1 "/content/media/%03d.avi"
# !mv "/content/youtube.mp4" "/content/video.mp4"
# Out:
# ...
# [youtube] xk3BvNLeNgw: Downloading webpage
# [youtube] xk3BvNLeNgw: Downloading android player API JSON
# [info] xk3BvNLeNgw: Downloading 1 format(s): 136
# [download] Destination: /content/youtube.mp4
# [download] 100% of 24.82MiB in 00:01
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
# !nvcc --version
# !nvidia-smi
print(torch.cuda.is_available())
print(torch.version.cuda)
#!pip install cython-bbox
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Fri Apr  1 05:05:42 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    25W / 149W |      0MiB / 11441MiB |      0%      Default |
# ...

# %%
import os
import signal

def handler(signum, frame):
    raise Exception("Timed out!")

os.chdir('/content/drive/My Drive/AlphaPose')
! ls

# Run AlphaPose on multiple videos
for i in os.listdir('/content/media/'):
  filepath = os.path.join('/content/media/', i)
  # Run demo_interference.py, if takes longer than 3 minutes to run, break
  signal.signal(signal.SIGALRM, handler)
  signal.alarm(240)
  try:
    # !python3 scripts/demo_inference.py --cfg configs/halpe_68_noface/resnet/256x192_res50_lr1e-3_2x-dcn-combined.yaml --checkpoint pretrained_models/noface_fast50_dcn_combined_256x192.pth  --video $filepath --outdir examples/res --save_video --pose_track
  except Exception as e:
    print(e)
    # Write the video name to log
    with open('/content/log.txt', 'a') as f:
      f.write(i + '\n')
    continue
  signal.alarm(0)
  # Rename the result json file
  os.rename('examples/res/alphapose-results.json', 'examples/res/' + i[:-4] + '_res.json')

# ! ls examples/res/vis
# Out:
# alphapose	    configs   examples		 README.md  setup.py
# alphapose.egg-info  detector  LICENSE		 scripts    trackers
# build		    docs      pretrained_models  setup.cfg
# Loading pose model from pretrained_models/noface_fast50_dcn_combined_256x192.pth...
# Loading YOLO model..
# loading reid model from trackers/weights/osnet_ain_x1_0_msmt17_256x128_amsgrad_ep50_lr0.0015_coslr_b64_fb10_softmax_labsmth_flip_jitter.pth...
#   0% 1/256 [00:06<26:38,  6.27s/it]Could not find encoder for codec id 27: Encoder not found
# Try to use other video encoders...
#   2% 6/256 [00:06<03:35,  1.16it/s]/content/drive/MyDrive/AlphaPose/trackers/__init__.py:19: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   new_hm = torch.Tensor(new_hm).to(args.device)
# ...
